# %%
import edw_analysis as edw

# %%
edw.analyze_monthly_trends_and_seasonality(show_plots=True)
# Out:
# Monthly warming rate (°C/decade):
#   Llanganuco:    0.404 °C/decade
#   Quilcayhuanca: 0.559 °C/decade

# %%
edw.analyze_edw(show_plots=True)
# Out:
# EDW summary (ΔT and lapse rate) — monthly means:
#   ΔT (high − low) mean: 0.263 °C
#   Lapse rate mean:      0.105 °C/100m

# %%
edw.analyze_daily_extremes(show_plots=True)
# Out:
# Freezing days per year — Llanganuco:
# date
# 2021-12-31    0
# 2022-12-31    0
# 2023-12-31    0
# 2024-12-31    0
# 2025-12-31    0
# Freq: YE-DEC, Name: tmean_c, dtype: int64
#
# Freezing days per year — Quilcayhuanca:
# date
# 2021-12-31    0
# 2022-12-31    0
# 2023-12-31    0
# 2024-12-31    0
# 2025-12-31    0
# Freq: YE-DEC, Name: tmean_c, dtype: int64
#
# Heatwave days per year (Tmean > 90th pct) — Llanganuco:
# date
# 2021-12-31      0
# 2022-12-31     10
# 2023-12-31     67
# 2024-12-31    107
# 2025-12-31     25
# Freq: YE-DEC, Name: tmean_c, dtype: int64
#
# Heatwave days per year (Tmean > 90th pct) — Quilcayhuanca:
# date
# 2021-12-31     22
# 2022-12-31     13
# 2023-12-31     19
# 2024-12-31    105
# 2025-12-31     29
# Freq: YE-DEC, Name: tmean_c, dtype: int64

# %%
edw.analyze_hydro_indices(show_plots=True)
# Out:
# Hydrological indices summary — Llanganuco:
#     hydro_year  pdd_degC_sum  n_freezing_days  n_days_p>=20.0mm
# 18        2022   1104.945083                0                 0
# 19        2023   2995.988681                0                 0
# 20        2024   3278.377708                0                 1
# 21        2025   2988.994458                0                 4
# 22        2026    561.676193                0                 0
#
# Hydrological indices summary — Quilcayhuanca:
#     hydro_year  pdd_degC_sum  n_freezing_days  n_days_p>=20.0mm
# 9         2022   2736.810893                0                 3
# 10        2023   2307.567386                0                 8
# 11        2024   2410.575765                0                 0
# 12        2025   2868.942895                0                 8
# 13        2026    541.219064                0                 1
